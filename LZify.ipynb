# %% [markdown]
# ## Rythme Generation Using LZify

# %%
def IPMotif(text, dictionary):
    """Compute an associative dictionary (the motif dictionary)."""
    
    motif = ""
    result = []
    for c in text:
        motif = motif + c
        if motif in dictionary:
            # Increase count for existing motif
#            print '%s in dictionary' % motif
            dictionary[motif] += 1
        else:
            # Add motif to the dictionary.
            dictionary[motif] = 1
            motif = ""
#            print 'add %s to dictionary' % motif

    return dictionary

# %%
from music21 import *

chorales = corpus.search('bach', fileExtensions='xml')

# %%
dict1 = {}
for i in range(len(chorales)):

    bwv = chorales[i].parse()
    sop = bwv.parts['Soprano']
    
    if sop is None:
        continue

    text = ""
    for note in sop.flat.notes:
        
        dur = int(note.duration.quarterLength * 4)
        
        text += str(dur)
         
    dict1 = IPMotif(text, dict1)

print(dict1)
# Out:
# {'4': 1486, '44': 1157, '444': 936, '4444': 716, '44444': 541, '444444': 366, '8': 224, '4444444': 251, '44444444': 209, '44444448': 18, '48': 118, '88': 51, '84': 139, '444444444': 175, '884': 24, '444448': 79, '8844': 20, '448': 68, '888': 16, '1': 147, '6': 68, '88444': 14, '488': 10, '16': 17, '884444': 12, '8888': 9, '168': 3, '844': 88, '4484': 31, '4881': 1, '61': 5, '616': 2, '4444444444': 146, '444444442': 17, '2': 718, '44444444444': 125, '444444444444': 97, '22': 229, '44442': 77, '24': 330, '4444442': 33, '244': 215, '42': 138, '242': 57, '2444': 171, '4444444444444': 72, '224': 125, '444442': 57, '24444': 132, '2244': 101, '4444444442': 11, '28': 78, '4442': 101, '11': 27, '22444': 80, '4444448': 64, '422': 128, '444444444442': 15, '284': 61, '224444': 64, '4444422': 49, '2244444': 45, '44444444444444': 51, '44422': 92, '2242': 12, '44444224': 31, '4224': 82, '42244': 65, '442': 111, '2446': 3, '221': 6, '12': 61, '2844': 39, '4422': 104, '444422': 74, '44224': 66, '4444446': 4, '2422': 50, '4446': 16, '248': 27, '484': 98, '848': 32, '41': 22, '21': 27, '24448': 15, '46': 28, '241': 14, '24446': 2, '2484': 14, '8448': 10, '8444': 66, '462': 26, '4226': 4, '212': 16, '224442': 6, '244444': 99, '444444444448': 4, '444444444444444': 38, '4448': 73, '444444444446': 5, '244441': 4, '2444444': 64, '444446': 18, '2444412': 2, '44462': 14, '44441': 17, '2444448': 13, '4444444444446': 5, '2448': 14, '22444444': 34, '444222': 15, '243': 3, '14': 31, '44444462': 3, '4444444444422': 13, '2243': 1, '144': 19, '224444444': 29, '44222': 22, '2431': 2, '442244': 51, '44444442': 18, '222': 78, '43': 2, '1444': 12, '44446': 12, '24444444': 43, '4444222': 7, '24314': 1, '44444444444448': 9, '4444224': 55, '44444422': 31, '2222': 33, '4444462': 17, '4481': 12, '442222': 21, '444444224': 24, '228': 15, '44442244': 40, '444422444': 32, '44442242': 7, '44444484': 44, '44488': 15, '4486': 2, '28442': 4, '244484': 11, '22442': 13, '244444444': 32, '412': 19, '224422': 12, '4444444441': 4, '2444442': 13, '24444442': 11, '24228': 10, '444224': 57, '44442222': 6, '44444444442': 11, '244444422': 10, '4444224444': 26, '88888': 7, '888888': 2, '124': 26, '8888888': 1, '886': 1, '288': 7, '881': 5, '2486': 1, '216': 2, '62': 28, '628': 4, '83': 1, '44444624': 14, '4444484': 64, '444446244': 11, '44448': 65, '444444444444448': 9, '44444444444224': 7, '4444444444444444': 30, '444444422': 17, '44444444444444444': 22, '444624': 12, '624': 15, '44228': 10, '444462': 11, '4624': 20, '442284': 6, '4446246': 2, '24442': 16, '28444': 34, '46246': 2, '244422': 15, '846': 4, '2412': 13, '6246': 1, '24124': 9, '44443': 1, '18': 10, '2244444444': 21, '1242': 5, '284442': 8, '241242': 3, '2844422': 7, '4422224': 14, '122': 11, '24222': 6, '2444222': 2, '24481': 6, '6161': 1, '4446244': 9, '441': 18, '2444844': 9, '81': 15, '244462': 1, '444412': 14, '44462444': 7, '8881': 4, '2488': 10, '8441': 2, '68': 5, '88812': 2, '4844': 50, '12424': 1, '88881': 1, '688': 4, '8816': 3, '888124': 1, '84412': 1, '424': 1, '444444844': 39, '444228': 15, '84444': 56, '44844': 26, '4442288': 5, '4444448444': 36, '226': 4, '4444444422': 16, '22422': 11, '4124': 14, '444444448': 12, '622': 5, '24844': 9, '4422444': 36, '422442': 6, '44442244444': 21, '44484': 51, '4442242': 7, '2442': 17, '2444228': 2, '444422422': 6, '4444444224': 14, '4488': 16, '446': 10, '28444224': 4, '84442': 7, '244442': 15, '24884': 6, '44444842': 2, '2441': 4, '2444441': 6, '444444444444444444': 17, '22444444444': 16, '4444444444444444444': 8, '442242': 5, '111': 4, '2444444444': 26, '4441': 18, '121': 3, '2444421': 2, '142': 7, '24444422': 10, '1244': 15, '421': 6, '1221': 4, '24444412': 4, '44226': 2, '4442248': 13, '422444': 55, '48444': 40, '44221': 2, '2444224': 10, '842': 4, '244448': 12, '4848': 36, '48484': 35, '8484': 31, '84848': 13, '48448': 6, '8462': 3, '46244': 13, '2244422': 4, '844442': 8, '2842': 6, '24226': 2, '2124': 5, '4462': 9, '12444': 13, '4228': 24, '4224441': 1, '44444844': 5 ...

# %%
def IPContinuation(dict1):
    """Compute continuation dictionary from a motif dictionary"""
    
    dict2 = {}
    for Wk in dict1:
        counter = dict1[Wk]
        W = Wk[:-1]
        #print 'W =',W
        k = Wk[-1]
        #print 'k-',k
        if W in dict2:
            dict2[W].append((k,counter))
            #print 'dict2', dict2
        else:
            dict2[W] = [(k,counter)]
            #print 'dict2', dict2
    dict2 = Normalize(dict2)    
    return dict2
                    
                    
def Normalize(dict2):
    """Turns the counters in every element of dict2 to probabilities"""
    
    for W in dict2:
        cnt = [tup[1] for tup in dict2[W]]
        ttl = sum(cnt)
        for k,tup in enumerate(dict2[W]):
            dict2[W][k] = (tup[0],float(tup[1])/ttl)
    return dict2

# %%
dict2 = IPContinuation(dict1)
print(dict2)
# Out:
# {'': [('4', 0.5596986817325801), ('8', 0.08436911487758945), ('1', 0.05536723163841808), ('6', 0.025612052730696798), ('2', 0.2704331450094162), ('3', 0.0007532956685499058), ('0', 0.003766478342749529)], '4': [('4', 0.7897610921501707), ('8', 0.08054607508532423), ('2', 0.09419795221843004), ('1', 0.015017064846416382), ('6', 0.01911262798634812), ('3', 0.0013651877133105802)], '44': [('4', 0.8174672489082969), ('8', 0.059388646288209605), ('2', 0.09694323144104804), ('1', 0.01572052401746725), ('6', 0.008733624454148471), ('3', 0.0017467248908296944)], '444': [('4', 0.7723840345199569), ('2', 0.10895361380798274), ('6', 0.017259978425026967), ('8', 0.07874865156418555), ('1', 0.019417475728155338), ('3', 0.003236245954692557)], '4444': [('4', 0.758765778401122), ('2', 0.10799438990182328), ('1', 0.023842917251051893), ('6', 0.016830294530154277), ('8', 0.091164095371669), ('3', 0.001402524544179523)], '44444': [('4', 0.6790352504638218), ('8', 0.14656771799628943), ('2', 0.10575139146567718), ('6', 0.03339517625231911), ('1', 0.03339517625231911), ('3', 0.0018552875695732839)], '444444': [('4', 0.6933701657458563), ('2', 0.09116022099447514), ('8', 0.17679558011049723), ('6', 0.011049723756906077), ('1', 0.027624309392265192)], '4444444': [('4', 0.836), ('8', 0.072), ('2', 0.072), ('1', 0.004), ('6', 0.012), ('3', 0.004)], '8': [('8', 0.24170616113744076), ('4', 0.6587677725118484), ('3', 0.004739336492890996), ('1', 0.07109004739336493), ('2', 0.023696682464454975)], '44444444': [('4', 0.8454106280193237), ('2', 0.0821256038647343), ('8', 0.057971014492753624), ('6', 0.00966183574879227), ('1', 0.004830917874396135)], '88': [('4', 0.5106382978723404), ('8', 0.3404255319148936), ('6', 0.02127659574468085), ('1', 0.10638297872340426), ('2', 0.02127659574468085)], '884': [('4', 0.8695652173913043), ('8', 0.043478260869565216), ('2', 0.08695652173913043)], '8844': [('4', 0.7368421052631579), ('8', 0.10526315789473684), ('6', 0.05263157894736842), ('2', 0.10526315789473684)], '48': [('8', 0.08695652173913043), ('4', 0.8521739130434782), ('2', 0.043478260869565216), ('1', 0.017391304347826087)], '1': [('6', 0.11643835616438356), ('1', 0.18493150684931506), ('2', 0.4178082191780822), ('4', 0.21232876712328766), ('8', 0.0684931506849315)], '88444': [('4', 0.9230769230769231), ('2', 0.07692307692307693)], '888': [('8', 0.6), ('1', 0.26666666666666666), ('4', 0.13333333333333333)], '16': [('8', 0.3), ('2', 0.3), ('4', 0.2), ('1', 0.2)], '84': [('4', 0.6616541353383458), ('8', 0.24060150375939848), ('6', 0.03007518796992481), ('2', 0.03007518796992481), ('1', 0.03007518796992481), ('0', 0.007518796992481203)], '448': [('4', 0.484375), ('1', 0.1875), ('6', 0.03125), ('8', 0.25), ('2', 0.046875)], '488': [('1', 0.1111111111111111), ('8', 0.1111111111111111), ('4', 0.7777777777777778)], '6': [('1', 0.09433962264150944), ('2', 0.5283018867924528), ('8', 0.09433962264150944), ('4', 0.1509433962264151), ('6', 0.1320754716981132)], '61': [('6', 0.5), ('1', 0.5)], '444444444': [('4', 0.863905325443787), ('2', 0.0650887573964497), ('1', 0.023668639053254437), ('6', 0.01775147928994083), ('8', 0.029585798816568046)], '4444444444': [('4', 0.8680555555555556), ('2', 0.0763888888888889), ('8', 0.034722222222222224), ('1', 0.006944444444444444), ('6', 0.013888888888888888)], '44444444444': [('4', 0.7950819672131147), ('2', 0.12295081967213115), ('8', 0.03278688524590164), ('6', 0.040983606557377046), ('1', 0.00819672131147541)], '2': [('2', 0.34077380952380953), ('4', 0.49107142857142855), ('8', 0.11607142857142858), ('1', 0.04017857142857143), ('6', 0.010416666666666666), ('3', 0.001488095238095238)], '24': [('4', 0.6574923547400612), ('2', 0.1743119266055046), ('8', 0.08256880733944955), ('1', 0.04281345565749235), ('3', 0.009174311926605505), ('6', 0.03363914373088685)], '244': [('4', 0.8181818181818182), ('6', 0.014354066985645933), ('8', 0.06698564593301436), ('2', 0.08133971291866028), ('1', 0.019138755980861243)], '444444444444': [('4', 0.79 ...

# %%
from numpy.random import multinomial as randm
from numpy import where

def IPGenerate(n,dict2):
    p = 0
    out = ""
    dur = 0
    while True:
        while True:
            context = out[-p:]
            if context in dict2:
                prob = [tup[1] for tup in dict2[context]]
                conti = where(randm(1,prob))[0][0]
                cont = dict2[context][conti][0]
                dur += int(cont)
                out = out + cont
#                print prob, conti, cont, out
                break
            else:
                p = p-1
                
        if dur > n:
            break
        
    return out

# %%
rythme = IPGenerate(200, dict2)

# %%
with open('rythme.txt', 'w') as f:
    f.write(text)
    
print(list(rythme))
# Out:
# ['4', '8', '4', '8', '4', '1', '2', '8', '4', '8', '4', '8', '4', '1', '2', '2', '2', '4', '4', '4', '4', '4', '4', '4', '4', '4', '4', '4', '2', '2', '4', '4', '4', '4', '4', '4', '4', '1', '2', '4', '4', '4', '4', '4', '1', '2', '4', '4', '4', '4', '4', '8']

# %% [markdown]
# ## Spatialization Generation Using Markov Chain

# %%
def Markov(text,order=0):
    """Compute a Markov models (fixed length motif dictionary)."""
    
    dict3 = {}
    for i in range(len(text)-order):
        W = text[i:i+order]
        #print 'W', W
        k  = text[i+order]
        #print 'k', k
        if W in dict3:
            if k in list(zip(*dict3[W]))[0]:
                dict3[W][k] += 1
                #print('dict', dict3)
            else:
                dict3[W][k] = 1
                #print('dict', dict3)
        else:
            dict3[W] = {k:1}
            #print('dict', dict3)

    for x in dict3:
        dict3[x] = list(dict3[x].items())
    dict3 = Normalize(dict3)    
    return dict3

# %%
from collections import Counter

pitch_lookup = {
    'C': 0,
    'D': 1,
    'E': 2,
    'F': 3,
    'G': 4,
    'A': 5,
    'B': 6,
}

pitch = ''
for i in range(len(chorales)):

    bwv = chorales[i].parse()
    sop = bwv.parts['Soprano']
    
    if sop is None:
        continue

    for note in sop.flat.notes:
        
        pic = str(note.pitch)
        
        if len(pic) > 2:
            pitch += str(7)
        else:
            pitch += str(pitch_lookup[pic[0]])

print(Counter(list(pitch)))
# Out:
# Counter({'7': 4220, '5': 3297, '1': 3076, '6': 2679, '0': 2374, '4': 2309, '2': 1879, '3': 1067})

# %%
def MaxOrder(text,order):
    dictall = {}
    for o in range(order):
        dicto = Markov(text,o)
        dictall.update(dicto)
    return dictall

# %%
dictM1 = MaxOrder(pitch,5)
print(dictM1)
# Out:
# {'': [('3', 0.05105018898617291), ('0', 0.11358308214917946), ('5', 0.1577436486292522), ('1', 0.14716999186641788), ('2', 0.08990000478446007), ('7', 0.2019042151093249), ('4', 0.11047318310128702), ('6', 0.12817568537390556)], '3': [('0', 0.05060918462980318), ('2', 0.274601686972821), ('3', 0.1471415182755389), ('1', 0.04967197750702906), ('4', 0.23711340206185566), ('5', 0.038425492033739454), ('7', 0.19962511715089035), ('6', 0.0028116213683223993)], '0': [('5', 0.06402695871946082), ('1', 0.2695871946082561), ('0', 0.15332771693344566), ('7', 0.17944397641112048), ('4', 0.03327716933445661), ('6', 0.2704296545914069), ('3', 0.018955349620893007), ('2', 0.010951979780960405)], '5': [('3', 0.022747952684258416), ('1', 0.05398847437063998), ('4', 0.29693660903851987), ('0', 0.022747952684258416), ('5', 0.1710646041856233), ('7', 0.16681831968456173), ('6', 0.24749772520473157), ('2', 0.018198362147406732)], '1': [('1', 0.1771781534460338), ('0', 0.24869960988296488), ('2', 0.18530559167750324), ('3', 0.016254876462938883), ('7', 0.24804941482444734), ('5', 0.053315994798439535), ('4', 0.035435630689206764), ('6', 0.03576072821846554)], '2': [('3', 0.10164981373070782), ('1', 0.3922299095263438), ('7', 0.1836083022884513), ('2', 0.14741883980840872), ('5', 0.06599254922831294), ('4', 0.026077700904736562), ('6', 0.050026609898882385), ('0', 0.03299627461415647)], '7': [('5', 0.14407582938388624), ('1', 0.18127962085308058), ('3', 0.03104265402843602), ('4', 0.08767772511848342), ('0', 0.08317535545023697), ('7', 0.2381516587677725), ('6', 0.12677725118483413), ('2', 0.10781990521327015)], '4': [('3', 0.18067590987868284), ('4', 0.17287694974003467), ('5', 0.292894280762565), ('7', 0.18977469670710573), ('1', 0.0402946273830156), ('0', 0.058925476603119586), ('6', 0.02859618717504333), ('2', 0.03596187175043328)], '6': [('5', 0.3613288540500187), ('0', 0.2116461366181411), ('2', 0.0429264650989175), ('6', 0.1541620007465472), ('7', 0.1791713325867861), ('1', 0.024262784621127288), ('4', 0.026502426278462114)], '30': [('5', 0.16666666666666666), ('1', 0.46296296296296297), ('0', 0.16666666666666666), ('6', 0.018518518518518517), ('7', 0.12962962962962962), ('4', 0.05555555555555555)], '05': [('3', 0.08552631578947369), ('1', 0.07894736842105263), ('0', 0.06578947368421052), ('5', 0.17105263157894737), ('4', 0.29605263157894735), ('7', 0.18421052631578946), ('6', 0.1118421052631579), ('2', 0.006578947368421052)], '53': [('0', 0.10666666666666667), ('4', 0.32), ('2', 0.2), ('3', 0.14666666666666667), ('7', 0.12), ('1', 0.06666666666666667), ('5', 0.04)], '01': [('1', 0.146875), ('2', 0.2046875), ('7', 0.2375), ('0', 0.2859375), ('6', 0.059375), ('5', 0.040625), ('4', 0.0171875), ('3', 0.0078125)], '11': [('0', 0.22385321100917432), ('1', 0.1926605504587156), ('7', 0.26605504587155965), ('2', 0.15412844036697249), ('6', 0.023853211009174313), ('5', 0.07889908256880734), ('4', 0.05321100917431193), ('3', 0.007339449541284404)], '10': [('0', 0.13856209150326798), ('5', 0.02875816993464052), ('7', 0.26143790849673204), ('6', 0.38823529411764707), ('4', 0.027450980392156862), ('1', 0.12418300653594772), ('2', 0.01437908496732026), ('3', 0.01699346405228758)], '00': [('1', 0.23351648351648352), ('7', 0.21153846153846154), ('0', 0.17307692307692307), ('4', 0.057692307692307696), ('6', 0.25274725274725274), ('3', 0.02197802197802198), ('2', 0.013736263736263736), ('5', 0.03571428571428571)], '12': [('3', 0.18070175438596492), ('1', 0.34035087719298246), ('7', 0.19649122807017544), ('2', 0.1631578947368421), ('6', 0.03333333333333333), ('0', 0.04912280701754386), ('4', 0.014035087719298246), ('5', 0.02280701754385965)], '23': [('2', 0.39790575916230364), ('3', 0.14659685863874344), ('1', 0.08376963350785341), ('4', 0.31413612565445026), ('0', 0.005235602094240838), ('5', 0.04712041884816754), ('7', 0.005235602094240838)], '32': [('1', 0.6177474402730375), ('4', 0.034129692832764506), ('0', 0.051194539249146756), ('2', 0.08873720136518772 ...

# %%
spatial = IPGenerate(len(rythme), dictM1)
with open('spatial.txt', 'w') as f:
    f.write(spatial)
    
print(list(spatial))
# Out:
# ['1', '5', '1', '4', '5', '7', '4', '3', '5', '6', '0', '5', '4', '4']
